# %% [markdown]
# ## Problem Statement

# %% [markdown]
# Predict a full year worth of sales for three items at three different countries. The data runs from 01/01/2015 to 31/12/2018. There is one dependent variable: Sales amount. The others variables are: Dates, Country, Store, Product.

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### Outcomes:
# The following questions needed answer:
# 1. Are there presence seasonality in our dataset?
# 2. Are the sales affected by Country?
# 3. Are the sales affected by Product?
# 4. Are the sales affected by Store?

# %% [markdown]
# ### Our Sales as a whole

# %%
#Importing data and neccessary library:
import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns

# %%
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")
df =  pd.read_csv("train.csv", parse_dates=["date"], index_col=["row_id"])

# %%
train.head()
# Out:
#    row_id        date  country       store         product  num_sold
# 0       0  2015-01-01  Finland  KaggleMart      Kaggle Mug       329
# 1       1  2015-01-01  Finland  KaggleMart      Kaggle Hat       520
# 2       2  2015-01-01  Finland  KaggleMart  Kaggle Sticker       146
# 3       3  2015-01-01  Finland  KaggleRama      Kaggle Mug       572
# 4       4  2015-01-01  Finland  KaggleRama      Kaggle Hat       911

# %%
train.describe()
# Out:
#              row_id      num_sold
# count  26298.000000  26298.000000
# mean   13148.500000    387.533577
# std     7591.723026    266.076193
# min        0.000000     70.000000
# 25%     6574.250000    190.000000
# 50%    13148.500000    315.000000
# 75%    19722.750000    510.000000
# max    26297.000000   2884.000000

# %%
#Daily Sales
daily_sales = df.groupby(["date"]).sum()
fig, ax = plt.subplots(figsize = (18,8))
sns.lineplot(data = daily_sales, x = "date", y = "num_sold")
plt.show()

# %%
#Sales by Country
country_sales = df.groupby(["date", "country"]).sum()
fig, ax = plt.subplots(figsize = (18,8))
sns.lineplot(data = country_sales, x = "date", y = "num_sold", hue="country")
plt.show()

# %%
#Sales by Store
store_sales = df.groupby(["date", "store"]).sum()
fig, ax = plt.subplots(figsize = (18,8))
sns.lineplot(data = store_sales, x = "date", y = "num_sold", hue="store")
plt.show()

# %%
#Sales by Product
product_sales = df.groupby(["date", "product"]).sum()
fig, ax = plt.subplots(figsize = (18,8))
sns.lineplot(data = product_sales, x = "date", y = "num_sold", hue="product")
plt.show()

# %% [markdown]
# ## Data Preparation

# %% [markdown]
# Cleaning data for SARIMAX

# %% [markdown]
# ## Model Building

# %% [markdown]
# ## Evaluation
